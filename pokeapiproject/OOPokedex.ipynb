# %%
class Pokedex:
    def __init__(self):
        self.name = None
        self.types = []
        self.abilities = []
        self.weight = None
        self.poke = ""

    def pokeapicall(self, pokeName):
        import requests as r
        req = r.get(f'https://pokeapi.co/api/v2/pokemon/{pokeName}')
        if req.status_code == 200:
            api = req.json()
        else:
            print('Ran into error: {req.status_code}')
            return 
   
        self.name = api['name'],
        self.types =  [x['type']['name'] for x in api['types']],
        self.abilities = [x['ability']['name'] for x in api['abilities']],
        self.weight = api['weight']
    
    #Talked to Alex, he mentioned that if I wanted to randomize by pokemon names to
    #create multiple lists with dictionaires within that list (used by previous api code)
    #but i was having issues randomizing and then a multitude of other errors.
    #it's 10 pm I have to throw in the towel. I feel that I would've been lost completing
    #this project I'm just confused now on the alternate route of actually using the
    #api data and filtering based on the specific data that I want? This is not clicking
    #with me. 
    
    def fly(self):
        flyer1 = []
        flyers = {'articuno': {'name': 'articuno',
            'types': ['ice', 'flying'],
            'abilities': ['pressure', 'snow-cloak'],
            'weight': 554},'lugia': {'name': 'lugia',
            'types': ['psychic', 'flying'],
            'abilities': ['pressure', 'multiscale'],
            'weight': 2160},
            'zapdos': {'name': 'zapdos',
            'types': ['electric', 'flying'],
            'abilities': ['pressure', 'static'],
            'weight': 526},
            'articuno': {'name': 'articuno',
            'types': ['ice', 'flying'],
            'abilities': ['pressure', 'snow-cloak'],
            'weight': 554},
            'moltres': {'name': 'moltres',
            'types': ['fire', 'flying'],
            'abilities': ['pressure', 'flame-body'],
            'weight': 600},
            'ho-oh': {'name': 'ho-oh',
            'types': ['fire', 'flying'],
            'abilities': ['pressure', 'regenerator'],
            'weight': 1990},'latias': {'name': 'latias',
            'types': ['dragon', 'psychic'],
            'abilities': ['levitate'],
            'weight': 400},
            'latios': {'name': 'latios',
            'types': ['dragon', 'psychic'],
            'abilities': ['levitate'],
            'weight': 600},
            'rayquaza': {'name': 'rayquaza',
            'types': ['dragon', 'flying'],
            'abilities': ['air-lock'],
            'weight': 2065}}
        userchoice = input("If you want to battle and catch a flying pokemon type 'fly'")
        if userchoice == 'fly':
            #from random import choice
            #randompokemon = choice(flyers1)
            #print(f'You caught a {randompokemon}, your pokedex has been updated!')
            print(random.choice(flyer1))
        else:
            print("So you don't want to catch a flying pokemo? Your loss!")
    
    def ele(self):
        volts = {'zapdos': {'name': 'zapdos',
            'types': ['electric', 'flying'],
            'abilities': ['pressure', 'static'],
            'weight': 526},'raikou': {'name': 'raikou',
            'types': ['electric'],'abilities': ['pressure', 'inner-focus'],
            'weight': 1780}, 'pikachu': {'name': 'pikachu', 'types': ['electric'],
            'abilities': ['static', 'lightning-rod'],'weight': 60}}
    def fir(self):  
        flames = {'entei': {'name': 'entei',
            'types': ['fire'],
            'abilities': ['pressure', 'inner-focus'],
            'weight': 1980},
            'moltres': {'name': 'moltres',
            'types': ['fire', 'flying'],
            'abilities': ['pressure', 'flame-body'],
            'weight': 600},
            'ho-oh': {'name': 'ho-oh',
            'types': ['fire', 'flying'],
            'abilities': ['pressure', 'regenerator'],
            'weight': 1990}}

    def wat(self):  
        waters = {'spheal': {'name': 'spheal',
            'types': ['ice', 'water'],
            'abilities': ['thick-fat', 'ice-body', 'oblivious'],
            'weight': 395},'suicune': {'name': 'suicune',
            'types': ['water'],
            'abilities': ['pressure', 'inner-focus'],
            'weight': 1870},
            'kyogre': {'name': 'kyogre',
            'types': ['water'],
            'abilities': ['drizzle'],
            'weight': 3520} }
    def psy(self):  
        mindreaders = {'lugia': {'name': 'lugia',
            'types': ['psychic', 'flying'],
            'abilities': ['pressure', 'multiscale'],
            'weight': 2160},
            'mew': {'name': 'mew',
            'types': ['psychic'],
            'abilities': ['synchronize'],
            'weight': 40},
            'mewtwo': {'name': 'mewtwo',
            'types': ['psychic'],
            'abilities': ['pressure', 'unnerve'],
            'weight': 1220},'latias':{'name': 'latias',
            'types': ['dragon', 'psychic'],
            'abilities': ['levitate'],
            'weight': 400},
            'latios': {'name': 'latios',
            'types': ['dragon', 'psychic'],
            'abilities': ['levitate'],
            'weight': 600}}

# %%
class Catch:
    def emall():
        print("""
Welcome Young Trainer!
Which type of Pokemon would you like to try and catch?
[1] Flying
[2] Electric
[3] Fire
[4] Water
[5] Psychic
        """)

    def run():
        Catch.emall()
        masterball = Pokedex()
        while True:
            choice = input('Pick a pokemon type that you want to catch!')
            if choice == '1':
                masterball.fly()
            elif choice == '2':
                masterball.ele()
            elif choice == '3':
                masterball.fir()
            elif choice == '4':
                masterball.wat()
            elif choice == '5':
                masterball.psy()
            else:
                print("Don't you want to go catch your first Pokemon? Type in '1' - '5'")

Catch.run()
# Out:
# Welcome Young Trainer!
# Which type of Pokemon would you like to try and catch?
# [1] Flying
# [2] Electric
# [3] Fire
# [4] Water
# [5] Psychic
#
# Pick a pokemon type that you want to catch!1
# If you want to battle and catch a flying pokemon type 'fly'fly
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-442ec676b241> in <module>
#      29                 print("Don't you want to go catch your first Pokemon? Type in '1' - '5'")
#      30
# ---> 31 Catch.run()
#
# <ipython-input-2-442ec676b241> in run()
#      17             choice = input('Pick a pokemon type that you want to catch!')
#      18             if choice == '1':
# ---> 19                 masterball.fly()
#      20             elif choice == '2':
#      21                 masterball.ele()
#
# <ipython-input-1-84883ed2874f> in fly(self)
#      63             #randompokemon = choice(flyers1)
# ...
